# %% [markdown]
# # Config

# %%
import pandas as pd
import matplotlib.pyplot as plt

import os
from dotenv import load_dotenv

from entsoe import EntsoePandasClient

load_dotenv()

# ENTSOE Token
entsoe_token = os.getenv("ENTSOE_API_TOKEN")

# ENTSOE Client
entsoe_client = EntsoePandasClient(api_key=entsoe_token)

# %% [markdown]
# # Fetch Actual & FCST Load

# %%
# Location
country_capital = "Madrid"
country_code = "ES"


# Period
today = pd.Timestamp.now(
    tz=f"Europe/{country_capital}"
).normalize()

yesterday=(pd.Timestamp.now(tz=f"Europe/{country_capital}")
    .normalize()
    - pd.Timedelta(days=1)
)
last_week=(pd.Timestamp.now(tz=f"Europe/{country_capital}")
    .normalize()
    - pd.Timedelta(days=7)
)

tomorrow =(pd.Timestamp.now(tz=f"Europe/{country_capital}")
    .normalize()
    + pd.Timedelta(days=1)
)


start=last_week
end=today


# ENTSOE Client
df = entsoe_client.query_load_and_forecast(
    country_code=country_code,
    start=last_week,
    end=today)

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 672 entries, 2026-08-04 00:00:00+02:00 to 2026-08-10 23:45:00+02:00
# Freq: 15min
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Forecasted Load  672 non-null    float64
#  1   Actual Load      672 non-null    float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
 df.describe().T
# Out:
#                  count          mean          std      min      25%      50%  \
# Forecasted Load  672.0  30151.537202  3524.942885  22962.0  27033.0  30697.5
# Actual Load      672.0  30218.339286  3530.512135  23180.0  27090.0  30686.0
#
#                       75%      max
# Forecasted Load  33266.75  35901.0
# Actual Load      33260.00  35768.0

# %%
df.head()
# Out:
#                            Forecasted Load  Actual Load
# 2026-08-04 00:00:00+02:00          30027.0      30068.0
# 2026-08-04 00:15:00+02:00          29609.0      29836.0
# 2026-08-04 00:30:00+02:00          29174.0      29368.0
# 2026-08-04 00:45:00+02:00          28732.0      28760.0
# 2026-08-04 01:00:00+02:00          28253.0      28368.0

# %%
df.tail()
# Out:
#                            Forecasted Load  Actual Load
# 2026-08-10 22:45:00+02:00          33012.0      31920.0
# 2026-08-10 23:00:00+02:00          32336.0      31312.0
# 2026-08-10 23:15:00+02:00          31754.0      30736.0
# 2026-08-10 23:30:00+02:00          31224.0      30104.0
# 2026-08-10 23:45:00+02:00          30733.0      29428.0

# %%
# Check that timestamps are unique
assert df.index.is_unique

# Check that timestamps are sorted
assert df.index.is_monotonic_increasing

# %%
pivot = pd.pivot_table(
    df,
    values=["Actual Load", "Forecasted Load"],
    index=df.index.date,
    aggfunc="mean"
)

pivot["Delta"] = pivot["Actual Load"] - pivot["Forecasted Load"]

print(pivot.round(2))
# Out:
#             Actual Load  Forecasted Load   Delta
# 2026-08-04     30931.54         30981.11  -49.57
# 2026-08-05     31208.29         31244.61  -36.32
# 2026-08-06     31583.62         31462.58  121.04
# 2026-08-07     31354.88         30958.32  396.55
# 2026-08-08     28915.12         28616.36  298.76
# 2026-08-09     27243.25         26961.70  281.55
# 2026-08-10     30291.67         30836.06 -544.40

# %%
# Plot \Actual vs Forecasted Electricity Load/



plt.figure(figsize=(14, 8))

plt.plot(
    pivot.index,
    pivot["Actual Load"],
    marker="o",
    linewidth=2,
    label="Actual Load"
)

plt.plot(
    pivot.index,
    pivot["Forecasted Load"],
    marker="o",
    linewidth=2,
    linestyle="--",
    label="Forecasted Load"
)

plt.title("Actual vs Forecasted Electricity Load", fontsize=16)
plt.xlabel("Date")
plt.ylabel("Load (MW)")
plt.legend()
plt.grid(alpha=0.3)

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Plot \Forecast Error: Actual Load − Fcst Load/

plt.figure(figsize=(14, 8))

plt.bar(
    pivot.index,
    pivot["Delta"]
)

plt.axhline(
    y=0,
    linewidth=1
)

plt.title("Forecast Error: Actual Load − Fcst Load", fontsize=16)
plt.xlabel("Date")
plt.ylabel("Delta (MW)")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
